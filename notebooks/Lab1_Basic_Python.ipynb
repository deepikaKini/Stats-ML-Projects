# %% [markdown]
# In this lab, you will try out some operations for different data types. Add a code block under each question and run it to show the expected output.

# %% [markdown]
# # 1. Operations for float:

# %% [markdown]
# 1.1 Round a given float to three decimal places
#
# expected input: x=89.323082
#
# expected output: 89.323

# %%
x = 89.323082
x = print('x =',round(x,3))
# Out:
# x = 89.323

# %% [markdown]
# 1.2 Check if a float is an integer or not
#
# expected input: x=239.01
#
# expected output: False

# %%
x = 239.01
float.is_integer(x)
# Out:
# False

# %% [markdown]
# # 2. Operations for string:

# %% [markdown]
# 2.1 Tokenize a string using whitespace as the delimiter
#
# Expected input: "We went to a park today",
#
# expected output: ['We', 'went', 'to', 'a', 'park', 'today']

# %%
x = "We went to a park today"
print(x.split())
# Out:
# ['We', 'went', 'to', 'a', 'park', 'today']

# %% [markdown]
# 2.2 Find if a string has numeric value,
#
# expected input: x="23.23"
#
# expected output: False

# %%
x = "23.23"
x.isnumeric()
# Out:
# False

# %% [markdown]
# 2.3 Check if a string variable contains a specified substring. Print "It is true" if it does or print "It is not".
#
# Expected input: x="I don't like this song", substring="music",
#
# expected result: It is not.
#
# You can use either find(), i.e., fullstring.find(substring) returns the index of the first occurence, will return -1 if the substring is not in the fullstring.
#
# You can also use: in, i.e., substring in fullstring. It returns True or False
#
# In case you need the syntax for if-else, here is the link: https://www.w3schools.com/python/python_conditions.asp

# %%
x = "I don't like this song"
substring = "music"
a = substring in x
if a == True:
  print("It is true")
elif a == False:
  print("It is not")
# Out:
# It is not

# %% [markdown]
# # 3 Operations for List and Set

# %% [markdown]
# 3.1 check if a string is a member of a list,
#
# expected input： thislist=['a','A', 'red',5], x='B'
# expected output: False

# %%
thislist=['a','A','red',5]
x='B'
x in thislist
# Out:
# False

# %% [markdown]
# 3.2 print the minimum value of a list
#
# expected input: thislist=[3,5,2,5,7]
# expected output: 2

# %%
thislist=[3,5,2,5,7]
min(thislist)
# Out:
# 2

# %% [markdown]
# 3.3 combine two sets using union()
# expected input: set1={"apple","orange","watermelon"}, set2={"banana","berry"}
# expected output:{'banana', 'watermelon', 'orange', 'apple', 'berry'}

# %%
set1={"apple","orange","watermelon"}
set2={"banana","berry"}
set2.union(set1)
# Out:
# {'apple', 'banana', 'berry', 'orange', 'watermelon'}

# %% [markdown]
# # 4. Operations for dictionary

# %% [markdown]
# Use zip() to create a dictionary for the first 5 letters in alphabet, i.e., A-E, where the key is their indexes (starting from 1) and the value is the letter.
#
# Get the value given the index, e.g, return 'E' if the index is 5

# %%
a = dict(zip([1,2,3,4,5],["A","B","C","D","E"]))
a[5]
# Out:
# 'E'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cf886d58-b5c5-494f-83a3-52efa87a4945' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
