# %% [markdown]
# ## Data Regression
#
# In this lab, you will work on generating linear regression models on the Carseat dataset where the targeted variable is "Sales".

# %% [markdown]
# 1. First mount the drive and load the Carseat data set.

# %% [markdown]
# 2. First, drop the categorical attributes, including ShelveLoc, Urban, and US.

# %% [markdown]
# 3. Clean the data: remove the rows with null values

# %% [markdown]
# 4. Let all the remaining attributes except for "Sales" as features (feature_df) and make "Sales" as the target variable (target_df).

# %% [markdown]
# 5. Split the dataset into trainining and testing sets where the ratio is 80% vs 20%. (hint: from sklearn.model_selection import train_test_split https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %% [markdown]
# 6. Generate a linear regression use all the features, output the coefficients, intercept, and R2 value. The expected output is
#
#
# ```
# Betas are  [ 0.09607115  0.01071816  0.13002373  0.0001983  -0.09477445 -0.04443894
#  -0.05465351]
# Intercept is  7.946168618481243
# R2 value is 0.5519055965165921
# ```

# %% [markdown]
# 7. Given the cofficients, explain which feature has the highest impact on the Sales, which features have negative impacts on the Sales. (Note: No code is needed for this question.)

# %% [markdown]
# 8. Apply the model to the testing set. Plot the residuals vs. predicted result and explain if the residuals are biased or not.

# %% [markdown]
# 9. Now let's perform a 10-fold Cross validation to evaluate the model. Output the scores for the 10 folds sepearately and also the mean of them. Use 'neg_mean_squared_error' to set the score.
# Hint_1: use sklearn.model_selection.cross_val_score for cross validation (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html)
#
# Hint_2: No need to do splitting when cross validation is performed.
#
# Expected output
#
#
# ```
# [-5.03439633 -3.49033152 -3.69117329 -3.9013924  -2.13203098 -3.08942165
#  -3.90786271 -4.24116403 -4.50765352 -3.95119533]
# -3.794662175867024
# ```

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cf886d58-b5c5-494f-83a3-52efa87a4945' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
